# %% [markdown]
# # Module 2: Object Oriented Programming
#
# ## Outline
#
# - What is OOP?
# - classes
#   - attributes
#     - "private" _attr
#   - methods
#     - self
# - inheritance
#   - super()
# - Best practices
#   - DRY principal
#   - [Cohesion and Coupling](https://www.youtube.com/watch?v=eiDyK_ofPPM)
# - Must know take away:
#   - Separating creation from use (Design pattern i)
#   - Name scope
