# %% [markdown]
# # Module 1: Introduction to Python
#
# Probably just point to some available resources, too many good
#
# ## Outline
#
# [Official guide](https://wiki.python.org/moin/BeginnersGuide)
#
# - basic data types/structure
#   - int, float, string, boolean
#   - isinstance()
#   - list, tuple, dictionary, set
#     - list: append, index, slice, sort, reverse
#     - tuple: immutable
#     - dictionary: keys, values, items, get, update
# - variables
# - operators
#   - arithmetic: +, -, *, /, **, +=, -=, *=
#   - comparison: ==, !=, >, <, >=, <=
#   - logical: and, or, not
# - control flow: for, while, if
# - functions
#   - define a function
#   - **typing**
#   - **lambda functions**
# - **context managers: with**
# - **list comprehensions**
#   - zip()
# - **style guide -> PEP8**
#
# **Bolded**: foreign to R users
